# %%
# 1. Print Function
print("ML for Drug Discovery")
# Out:
# ML for Drug Discovery

# %%
# 1.1 Print with Quotes
print("They said, 'ML for Drug Discovery is a great start'")
# Out:
# They said, 'ML for Drug Discovery is a great start'

# %%
# 1.2 Print with Split Lines
print("ML for\nDrug Discovery")
# Out:
# ML for
# Drug Discovery

# %%
# 2. Variables
